# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnsl/Graph-Functions-Py/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import *
from math import *
import sympy as sm
print("please input the range of f(x) in [a,b]")
a=input('a:')
b=input('b:')
a=int(a)
b=int(b)
x = np.linspace(a,b,1000)
a=input("f(x)= ")
def f(x): return  eval(a)    #####function to graph
plt.figure(1)
txt=sm.symbols('f(x)')
txt2=s.symbols("f'(x)")
plt.plot(x,f(x))
plt.axhline(color='black')
plt.axvline(color='black')
############################Differntiate of f(x)########################
def round_to_1(x):
  return round(x, -int(floor(log10(abs(x)))))
def fprime(x):
  dx=1/100
  return ((f(x+dx)-f(x))/dx)
################################################Graph tHE Derivative#############################################

plt.figure(2)
print("Graph of f'(x)")
plt.plot(x,fprime(x))
plt.axhline(color='black')
plt.axvline(color='black')

txt


###########################################By Hasan Saleh #############################################x
# Out:
# please input the range of f(x) in [a,b]
# a:0
# b:10
# f(x)= x**2+2
# Graph of f'(x)
# f(x)
